# %% [markdown]
# # **1. Basic Pandas Operations & Understanding the Data**
# - Import necessary libraries
# - Load the dataset using Pandas
# - Display first and last 5 rows
# - Print the shape, column names, and info summary of the dataset.

# %% [markdown]
# ##**Importing Libraries & Loading Dataset:**

# %%
# Import necessary libraries
import pandas as pd
from datetime import datetime  # For Time base Analysis


# Load the dataset using Pandas
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ##**Exploring Dataset**

# %%
# Displaying first 5 rows
df.head()

# Displaying last 5 rows
df.tail()

# Print the shape in terms of Rows and Columns
print(f"Row and Colums in a Dataset {df.shape}")

# print column names
print(f"\nColumn Names:\n{df.columns}")

# Displaying Data Types:
print(f"Data Types\n{df.dtypes}")

# Displaying Statistical Summary
print(f"\nStatistical Summary:\n{df.describe()}")

# Info summary of the dataset
print(f"\nInfo Summary:\n{df.info()}")
# Out:
# Row and Colums in a Dataset (8807, 12)
#
# Column Names:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Data Types
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object
#
# Statistical Summary:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
# ...

# %%
#  Info summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Identify duplicates

for col in df.columns:
    num_dupes = df[col].duplicated().sum()
    print(f"{col}:\t {num_dupes} duplicated values")
# Out:
# show_id:	 0 duplicated values
# type:	 8805 duplicated values
# title:	 0 duplicated values
# director:	 4278 duplicated values
# cast:	 1114 duplicated values
# country:	 8058 duplicated values
# date_added:	 7039 duplicated values
# release_year:	 8733 duplicated values
# rating:	 8789 duplicated values
# duration:	 8586 duplicated values
# listed_in:	 8293 duplicated values
# description:	 32 duplicated values

# %% [markdown]
# # **2. Data Wrangling**

# %% [markdown]
# ### Data Cleaning:
# - Check for missing values and count them per column
# - Drop all rows where the title or type is missing
# - Convert the date_added column to datetime format

# %%
# Check for missing values and count them per column

missing_values = df.isnull().sum()
print(f"Count for Missing Values \n{missing_values}\n per column")

# Drop all rows where the title or type is missing
df_clean = df.copy()

df_clean.dropna(subset=['title', 'type'], inplace=True)
print("\n\nDropping all Rows where the title or type is missing\n")
df_clean

# Convert the `date_added` column to datetime format
df_clean['date_added'] = pd.to_datetime(df_clean['date_added'], format='mixed')   # dates in string format like `2024-07-01', 'July 3, 2025`
df_clean.info()
# Out:
# Count for Missing Values
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
#  per column
#
#
# Dropping all Rows where the title or type is missing
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
# ...

# %%
# Handle missing values with Descriptive Statistics

df_clean['director'].fillna('unknown', inplace=True)

df_clean['country'].mode()  # most frequent value
df_clean['country'].fillna('United States', inplace=True)

df_clean['cast'].fillna('not specified', inplace=True)

df_clean['rating'].mode()  # most frequent value
df_clean['rating'].fillna('TV-MA', inplace=True)

df_clean['duration'].fillna('not specified', inplace=True)

df_clean
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12744\2361257438.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean['director'].fillna('unknown', inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_12744\2361257438.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Filtering and indexing:
# - Show only movies released after 2015
# - Filter all shows from the country India
# - Select only Movie type entries with duration over 90 minutes

# %%
# Show only movies released after 2015
movies_after_2015 = df_clean[(df_clean['type'] == 'Movie') & (df_clean['release_year'] > 2015)]
movies_after_2015
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# 13       s14  Movie  Confessions of an Invisible Girl
# ...      ...    ...                               ...
# 8781   s8782  Movie           Yo-Kai Watch: The Movie
# 8782   s8783  Movie                       Yoga Hosers
# 8786   s8787  Movie                      You Can Tutu
# 8787   s8788  Movie         You Can’t Fight Christmas
# 8794   s8795  Movie                            اشتباك
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 9                    Theodore Melfi
# 12              Christian Schwochow
# 13                    Bruno Garotti
# ...                             ...
# 8781                    Mark Risley
# ...

# %%
# Filter all shows from the country India
india_shows = df_clean[df_clean['country'] == 'India']
india_shows
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                  unknown
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                  unknown
# 50       s51  TV Show                  Dharmakshetra                  unknown
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                  unknown
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                  unknown
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
# Select only Movie type entries with duration over 90 minutes

# Filter only movies
movies = df_clean[df_clean['type'] == 'Movie'].copy()

# Extract the numeric part of the duration, fill NaN values with 0, and convert to integer
movies['duration_numeric'] = movies['duration'].str.extract('(\d+)').fillna(0).astype(int)

# Filter movies with duration over 90 minutes
movies_over_90_minutes = movies[movies['duration_numeric'] > 90]
movies_over_90_minutes
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_12744\3289071778.py:7: SyntaxWarning: invalid escape sequence '\d'
#   movies['duration_numeric'] = movies['duration'].str.extract('(\d+)').fillna(0).astype(int)
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# 13       s14  Movie  Confessions of an Invisible Girl
# ...      ...    ...                               ...
# 8798   s8799  Movie                          Zed Plus
# 8799   s8800  Movie                             Zenda
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8806   s8807  Movie                            Zubaan
#
# ...

# %% [markdown]
# ### Column operations:
# - Create a new column called `release_decade` based on the release_year
# - Display unique values in type, rating, and country

# %%
# Create a new column called release_decade based on the release_year
df_clean['release_decade'] = (df_clean['release_year'] // 10) * 10
df_clean
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         not specified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Display unique values in type, rating, and country
unique_types = df_clean['type'].unique()   # Unique value in `Type`

unique_ratings = df_clean['rating'].unique()    # Unique value in `Rating`

unique_countries = df_clean['country'].unique()    # Unique value in `Country`

print(f"Unique Types: \n{unique_types}\n")
print(f"Unique Ratings: \n{unique_ratings}\n")
print(f"Unique Countries: \n{unique_countries}\n")
# Out:
# Unique Types:
# ['Movie' 'TV Show']
#
# Unique Ratings:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' 'TV-Y7-FV' 'UR']
#
# Unique Countries:
# ['United States' 'South Africa' 'India'
#  'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia'
#  'United Kingdom' 'Germany, Czech Republic' 'Mexico' 'Turkey' 'Australia'
#  'United States, India, France' 'Finland' 'China, Canada, United States'
#  'South Africa, United States, Japan' 'Nigeria' 'Japan'
#  'Spain, United States' 'France' 'Belgium' 'United Kingdom, United States'
#  'United States, United Kingdom' 'France, United States' 'South Korea'
#  'Spain' 'United States, Singapore' 'United Kingdom, Australia, France'
#  'United Kingdom, Australia, France, United States'
#  'United States, Canada' 'Germany, United States'
#  'South Africa, United States' 'United States, Mexico'
#  'United States, Italy, France, Japan'
# ...

# %% [markdown]
# ## Aggregations:
# - Group by type and count the number of titles in each category
# - Group by country and find the top 5 countries with the most titles
# - Group by rating and find average release year for each rating type

# %%
# Group by type and count the number of titles in each category
type_counts = df_clean.groupby('type')['title'].count()
print(type_counts)
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: title, dtype: int64

# %%
# Group by country and find the top 5 countries with the most titles
country_counts = df_clean.groupby('country')['title'].count()
top_5_countries = country_counts.nlargest(5)
print(top_5_countries)
# Out:
# country
# United States     3649
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Name: title, dtype: int64

# %%
# Group by rating and find average release year for each rating type
rating_release_year = df_clean.groupby('rating')['release_year'].mean()
print(rating_release_year)
# Out:
# rating
# 66 min      2015.000000
# 74 min      2017.000000
# 84 min      2010.000000
# G           1997.804878
# NC-17       2015.000000
# NR          2010.912500
# PG          2008.428571
# PG-13       2009.314286
# R           2010.471840
# TV-14       2013.655556
# TV-G        2015.745455
# TV-MA       2016.659608
# TV-PG       2013.529548
# TV-Y        2017.159609
# TV-Y7       2015.508982
# TV-Y7-FV    2014.833333
# UR          1999.333333
# Name: release_year, dtype: float64

# %% [markdown]
# ## Multiple aggregations:

# %%
# Group by release_year and show
df_clean.groupby('release_year')['type'].value_counts()
# Out:
# release_year  type
# 1925          TV Show      1
# 1942          Movie        2
# 1943          Movie        3
# 1944          Movie        3
# 1945          Movie        3
#                         ...
# 2019          TV Show    397
# 2020          Movie      517
#               TV Show    436
# 2021          TV Show    315
#               Movie      277
# Name: count, Length: 119, dtype: int64

# %%
# Total number of titles
total_titles = df_clean.groupby('release_year')['title'].count()
print(f"Total_titles: \n{total_titles}")

# Count of Movies and TV Shows separately
type_counts = df_clean.groupby(['release_year', 'type'])['title'].count().unstack(fill_value=0)
print(f"\nType Counts: \n{type_counts}")
# Out:
# Total_titles:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: title, Length: 74, dtype: int64
#
# Type Counts:
# type          Movie  TV Show
# release_year
# 1925              0        1
# 1942              2        0
# 1943              3        0
# 1944              3        0
# 1945              3        1
# ...             ...      ...
# 2017            767      265
# 2018            767      380
# 2019            633      397
# 2020            517      436
# 2021            277      315
#
# [74 rows x 2 columns]

# %% [markdown]
# ## Advanced:
# - Create a new column `is_recent` True if `release_year` > 2015
# - Group by country and count how many recent shows are there per country

# %%
#  Create a new column is_recent True if release_year > 2015
df_clean['is_recent'] = df_clean['release_year'] > 2015
df_clean
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         not specified  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Group by country and count how many recent shows are there per country
recent_shows_per_country = df_clean[df_clean['is_recent']].groupby('country')['title'].count()
print(f"Recent Shows: {recent_shows_per_country}")
# Out:
# Recent Shows: country
# , South Korea                                           1
# Argentina                                              46
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        1
# Argentina, France                                       1
#                                                        ..
# Uruguay, Guatemala                                      1
# Uruguay, Spain, Mexico                                  1
# Venezuela                                               1
# Vietnam                                                 5
# Zimbabwe                                                1
# Name: title, Length: 503, dtype: int64

# %% [markdown]
# # **3. Analysis Questions**
# Answer briefly:
# 1. What is the most common rating for TV Shows?
# 2. Which country has the most content on Netflix?
# 3. Are most Netflix titles older or recent (after 2015)?
# 4. Whats the average release year for Netflix Movies?

# %% [markdown]
# ## 📊 Netflix Content Analysis
#
# ### 1. What is the most common rating for TV Shows?
# **TV-MA** is the most common rating for TV Shows on Netflix.
#
# ---
#
# ### 2. Which country has the most content on Netflix?
# The **United States** has the highest number of titles on Netflix.
#
# ---
#
# ### 3. Are most Netflix titles older or recent (after 2015)?
# Most Netflix titles are **recent**, released **after 2015**.
#
# ---
#
# ### 4. What’s the average release year for Netflix Movies?
# The average release year for Netflix Movies is around **2014**.
